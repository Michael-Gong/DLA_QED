# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = mpl.cm.Reds
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.Normalize(vmin=0, vmax=4400)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap,
                                norm=norm,
                                orientation='horizontal',ticks=np.linspace(0,4400,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label('$\gamma$',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.

fig = plt.gcf()
fig.set_size_inches(10, 2)
plt.show()
fig.savefig('./colorbar_reds.png',format='png',dpi=160, transparent=True)
plt.close("all")

# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = mpl.cm.autumn
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.Normalize(vmin=0, vmax=500)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap,
                                norm=norm,
                                orientation='horizontal',ticks=np.linspace(0,500,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label(r'$\varepsilon_e$'+'[$m_ec^2$]',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.
plt.subplots_adjust(top=0.98, bottom=0.13, left=0.1, right=0.9, hspace=0.10, wspace=0.05)
fig = plt.gcf()
fig.set_size_inches(12, 2)
plt.show()
fig.savefig('./colorbar_autumn.png',format='png',dpi=160, transparent=True)
plt.close("all")

# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = mpl.cm.winter
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.Normalize(vmin=0, vmax=12000)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap,
                                norm=norm,
                                orientation='horizontal',ticks=np.linspace(0,10000,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label(r'$\varepsilon_e$'+'[$m_ec^2$]',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.
plt.subplots_adjust(top=0.98, bottom=0.13, left=0.1, right=0.9, hspace=0.10, wspace=0.05)
fig = plt.gcf()
fig.set_size_inches(12, 2)
plt.show()
fig.savefig('./colorbar_winter.png',format='png',dpi=160, transparent=True)
plt.close("all")

# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = mpl.cm.hot
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.Normalize(vmin=0, vmax=500)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap,
                                norm=norm,
                                orientation='horizontal',ticks=np.linspace(0,500,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label('$\epsilon_{\gamma}$ [MeV]',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.
plt.subplots_adjust(top=0.98, bottom=0.13, left=0.1, right=0.9, hspace=0.10, wspace=0.05)
fig = plt.gcf()
fig.set_size_inches(12, 2)
plt.show()
fig.savefig('./colorbar_hot.png',format='png',dpi=160, transparent=True)
plt.close("all")

# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = mpl.cm.rainbow
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.Normalize(vmin=0, vmax=1000)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap,
                                norm=norm,
                                orientation='horizontal',ticks=np.linspace(0,1000,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label('time [fs]',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.
plt.subplots_adjust(top=0.98, bottom=0.13, left=0.1, right=0.9, hspace=0.10, wspace=0.05)
fig = plt.gcf()
fig.set_size_inches(12, 2)
plt.show()
fig.savefig('./colorbar_rainbow.png',format='png',dpi=160, transparent=True)
plt.close("all")

# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

c_red = matplotlib.colors.colorConverter.to_rgba('tomato')
c_blue= matplotlib.colors.colorConverter.to_rgba('dodgerblue')
c_white_trans = matplotlib.colors.colorConverter.to_rgba('white',alpha = 0.0)
cmap_rb = matplotlib.colors.LinearSegmentedColormap.from_list('rb_cmap',[c_red,c_white_trans,c_blue],128)
cmap_br = matplotlib.colors.LinearSegmentedColormap.from_list('rb_cmap',[c_blue,c_white_trans,c_red],128)

# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap =cmap_br
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.Normalize(vmin=-200, vmax=200)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap,
                                norm=norm,
                                orientation='horizontal',ticks=np.linspace(-200,200,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label('$E_y\ [m_ec\omega/|e|]$',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.
plt.subplots_adjust(top=0.98, bottom=0.13, left=0.1, right=0.9, hspace=0.10, wspace=0.05)
fig = plt.gcf()
fig.set_size_inches(12, 2)
plt.show()
fig.savefig('./colorbar_PiYG.png',format='png',dpi=160, transparent=True)
plt.close("all")

# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

upper = matplotlib.cm.viridis(np.arange(256))
lower = np.ones((int(256/4),4))
for i in range(3):
    lower[:,i] = np.linspace(1, upper[0,i], lower.shape[0])
cmap = np.vstack(( lower, upper ))
mycolor_viridis = matplotlib.colors.ListedColormap(cmap, name='myColorMap', N=cmap.shape[0])

upper = matplotlib.cm.rainbow(np.arange(256))
lower = np.ones((int(256/4),4))
for i in range(3):
    lower[:,i] = np.linspace(1, upper[0,i], lower.shape[0])
cmap = np.vstack(( lower, upper ))
mycolor_rainbow = matplotlib.colors.ListedColormap(cmap, name='myColorMap', N=cmap.shape[0])

# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = mycolor_rainbow
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap,
                                norm=norm,
                                orientation='horizontal',ticks=np.logspace(0,2,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label('dI/d'+r'$\theta$'+'d'+r'$\varepsilon_\gamma$'+' [A.U.]',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.
plt.subplots_adjust(top=0.98, bottom=0.13, left=0.1, right=0.9, hspace=0.10, wspace=0.05)
fig = plt.gcf()
fig.set_size_inches(12, 2)
plt.show()
fig.savefig('./colorbar_my_rainbow.png',format='png',dpi=160, transparent=True)
plt.close("all")

# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

upper = matplotlib.cm.jet(np.arange(256))
lower = np.ones((int(256/4),4))
for i in range(3):
    lower[:,i] = np.linspace(1, upper[0,i], lower.shape[0])
cmap = np.vstack(( lower, upper ))
mycolor_jet = matplotlib.colors.ListedColormap(cmap, name='myColorMap', N=cmap.shape[0])


# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.1, 0.80, 0.8, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = mycolor_jet
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e4)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap,
                                norm=norm,
                                orientation='horizontal',ticks=np.logspace(0,4,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label('dN/d'+r'$\varepsilon_e$'+' [A.U.]',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.
plt.subplots_adjust(top=0.98, bottom=0.13, left=0.15, right=0.85, hspace=0.10, wspace=0.05)
fig = plt.gcf()
fig.set_size_inches(5, 2)
plt.show()
fig.savefig('./colorbar_my_jet.png',format='png',dpi=160, transparent=True)
plt.close("all")

# %%
'''
====================
Customized colorbars
====================

This example shows how to build colorbars without an attached mappable.
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib

font = {'family' : 'monospace',  
      'color'  : 'black',  
      'weight' : 'normal',  
      'size'   : 45,  
       }  
font_size=45

upper = matplotlib.cm.jet(np.arange(256))
lower = np.ones((int(256/4),4))
for i in range(3):
    lower[:,i] = np.linspace(1, upper[0,i], lower.shape[0])
cmap = np.vstack(( lower, upper ))
mycolor_jet = matplotlib.colors.ListedColormap(cmap, name='myColorMap', N=cmap.shape[0])


# Make a figure and axes with dimensions as desired.
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
#ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])
#ax3 = fig.add_axes([0.05, 0.15, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = mycolor_jet
Bz = -2*1*(1.0)**0.5
norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e4)
# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.


cb1 = mpl.colorbar.ColorbarBase(ax1, cmap='viridis',
                                norm=norm,
                                orientation='horizontal',ticks=np.logspace(0,4,3))
cb1.ax.set_xticklabels(cb1.ax.get_xticklabels(), fontsize=font_size)
cb1.set_label('dN/d'+r'$\varepsilon_e$'+' [A.U.]',fontdict=font)

# The second example illustrates the use of a ListedColormap, a
# BoundaryNorm, and extended ends to show the "over" and "under"
# value colors.
cmap = mpl.colors.ListedColormap(['r', 'g', 'b', 'c'])
cmap.set_over('0.25')
cmap.set_under('0.75')

# If a ListedColormap is used, the length of the bounds array must be
# one greater than the length of the color list.  The bounds must be
# monotonically increasing.
plt.subplots_adjust(top=0.98, bottom=0.13, left=0.1, right=0.9, hspace=0.10, wspace=0.05)
fig = plt.gcf()
fig.set_size_inches(12, 2)
plt.show()
fig.savefig('./colorbar_viridis.png',format='png',dpi=160, transparent=True)
plt.close("all")
